# %%
import json
import numpy as np
from pathlib import Path
import pandas as pd

# %% [markdown]
# # All folders of interest

# %%
def get_config_information(
        selected_dataset,
        target_name,
        data_type):
    
    if data_type not in ["AGPM_T1", "AGPM_T2", "AGPM_T4", "DITHER_T2",
                         "DITHER_T1"]:
        raise ValueError("data_type unknown.")

    # Create the final dict
    summary_dict = dict()
    summary_dict["target_name"] = target_name
    summary_dict["data_type"] = data_type

    # Global information
    summary_dict["Prog_ID"] = list(set(selected_dataset.index.get_level_values(0)))[0]
    summary_dict["Night_NR"] = list(set(selected_dataset.index.get_level_values(1)))[0]

    # Find Science and PSF data
    science_datasets = selected_dataset.xs(
        "OBJECT", level=3).xs(
        "SCIENCE", level=3)

    time_idx_list = list(enumerate(science_datasets[("total_time", "sum")]))
    time_idx_list = sorted(time_idx_list, key=lambda x: x[1])
    summary_dict["total_time"] = str(time_idx_list[-1][1])

    # Check for the PSF data
    if not data_type == "DITHER_T1":
        psf_idx = time_idx_list[-2][0]

        _, _, _, summary_dict["exp_time_psf"], nd_psf, _, pix_x_psf, pix_y_psf = \
            science_datasets.index[psf_idx]

        psf_data = science_datasets.iloc[psf_idx]
        summary_dict["image_size_psf"] = (
            int(pix_x_psf),
            int(pix_y_psf))

    # Get Files lists for the science data
    science_idx = time_idx_list[-1][0]
    _, _, _, summary_dict[
        "exp_time_science"], _, _, pix_x_science, pix_y_science = \
        science_datasets.index[science_idx]

    science_data = science_datasets.iloc[science_idx]

    if data_type in ["DITHER_T2", "DITHER_T1"]:
        pass

    elif data_type == "AGPM_T4":
        summary_dict["image_size_sky"] = (
            int(pix_x_science),
            int(pix_y_science))

    elif data_type == "AGPM_T2":
        sky_datasets = selected_dataset.xs(
            "SKY", level=3).xs(
            "SCIENCE", level=3)
        _, _, _, _, _, _, pix_x_sky, pix_y_sky = \
            sky_datasets.index[0]

        summary_dict["image_size_sky"] = (int(pix_x_sky), int(pix_y_sky))
    else:
        raise NotImplementedError()

    summary_dict["image_size_science"] = (
        int(pix_x_science),
        int(pix_y_science))
    
    # additional data
    summary_dict["cond_wind_speed"] = science_data[('WIND_SPEED', 'mean')]
    summary_dict["cond_seeing_fwhm"] = science_data[('AMBI_FWHM', 'mean')]
    summary_dict["cond_water_vapor"] = science_data[('Water_Vapor', 'mean')]
    summary_dict["cond_airmass"] = science_data[('Airmass', 'mean')]
    summary_dict["cond_tau_0"] = science_data[('AVG_Tau0', 'mean')]
    summary_dict["cond_adi_rotation"] = science_data[('POSANG_START', 'Total_ADI_rotation')]

    return summary_dict

# %% [markdown]
# # 1.) Load the dataset tables

# %%
dataset_table_dir = Path("/fast/mbonse/NACO/50_code/dataset_tables/")
rood_result_dir = Path("/fast/tgebhard/catnip/data/")

# %%
setups = [("agpm_type2_table.pkl", "AGPM_T2"),
          ("agpm_type4_table.pkl", "AGPM_T4"),
          #("dither_type1_table.pkl", "DITHER_T1"),
          ("dither_type2_table.pkl", "DITHER_T2")]

# %%
for pkl_file, dataset_type in setups:
    tmp_subtable_file = dataset_table_dir / Path(pkl_file)
    tmp_subtable = pd.read_pickle(tmp_subtable_file)
    
    stars_of_interest = list(set(tmp_subtable.index.get_level_values(0)))
    
    for tmp_target_name in stars_of_interest:
        print(tmp_target_name)
        sel_dataset = tmp_subtable.xs(tmp_target_name, level=0)

        for name, tmp_df in sel_dataset.groupby(level=["Program ID", "Night_NR"]):
            tmp_json = get_config_information(tmp_df, tmp_target_name.replace(" ", "-"), dataset_type)
            clean_prog_id = tmp_json["Prog_ID"].replace("(", "_").replace(")", "_").replace(".", "_")
            tmp_dataset_name = tmp_json["target_name"] + "_" + str(tmp_json["Night_NR"]) + "_" + clean_prog_id[:-1]

            tmp_json_file = rood_result_dir / Path(tmp_dataset_name + "/meta_information.json")
            if not tmp_json_file.is_file():
                print(tmp_json_file)
                continue

            # Load the current json
            with open(tmp_json_file) as f:
                d = json.load(f)
            tmp_json.update(d)

            # save the updated information
            with open(tmp_json_file, 'w', encoding='utf-8') as f:
                json.dump(tmp_json, f, ensure_ascii=False, indent=4)
# Out:
# HD209253
# HD37806
# HD222368
# /fast/tgebhard/catnip/data/HD222368_192_1101_C-0092_G/meta_information.json
# HD9672
# HD190073
# HD36112
# /fast/tgebhard/catnip/data/HD36112_17_1101_C-0092_D/meta_information.json
# HIP93449
# /fast/tgebhard/catnip/data/HIP93449_158_1101_C-0092_A/meta_information.json
# /fast/tgebhard/catnip/data/HIP93449_140_199_C-0065_A/meta_information.json
# HD95881
# HD188228
# HD38120
# HD870
# HD183324
# HD92945
# HD61005
# /fast/tgebhard/catnip/data/HD61005_15_096_C-0571_A/meta_information.json
# HD131511
# HD101412
# HD172555
# HD27290
# GAIA DR3 3314312226646863488
# HD7570
# HD16743
# HD107146
# GAIA DR3 6731196273845607168
# HD115892
# HD221853
# HD191849
# HD145964
# HD166348
# HD163296
# HD11171
# HD126062
# HD40136
# HD19994
# HD197481
# GAIA DR3 6049145880875631744
# HD10472
# HD72106
# HD135379
# HD1466
# HD152404
# HD90905
# HD202730
# HD1581
# /fast/tgebhard/catnip/data/HD1581_294_1101_C-0092_C/meta_information.json
# HD100546
# HD97048
# HD145689
# HD38206
# GJ699
# HD142527
# HD36910
# HD12039
# HD69830
# HD223352
# HD213398
# HD169142
# HD5133
# HD179520
# HD197890
# HD34282
# HD139614
# HD218511
# HD207129
# HD10647
# HD30495
# HD115617
# /fast/tgebhard/catnip/data/HD115617_142_1101_C-0092_E/meta_information.json
# HD71043
# HD169022
# HD199260
# HD143006
# HD181327
# HD203
# HD212695
# HD13246
# /fast/tgebhard/catnip/data/HD13246_242_199_C-0065_B/meta_information.json
# HD194636
# HD37411
# HD23484
# HD22484
# /fast/tgebhard/catnip/data/HD22484_294_1101_C-0092_C/meta_information.json
# HD181296
# HD46190
# HD141943
# HD144432
# HD146624
# HD3003
# HD71155
# HD35114
# HD21997
# HD223340
# HD31648
# HD15115
# HD215766
# HD196544
# /fast/tgebhard/catnip/data/HD196544_242_199_C-0065_B/meta_information.json
# HD10700
# HD37484
# HD35187
# HD142666
# HD139664
# HD220825
# HD2262
# HD22049
# HD193571
# HD206860
# HD202628
# /fast/tgebhard/catnip/data/HD202628_244_199_C-0065_B/meta_information.json
# HD72660
# HD76151
# HD158643
# HD105613
# HD192758
# HD113524
# /fast/tgebhard/catnip/data/HD113524_167_199_C-0065_B/meta_information.json
# HD111631
# HD144668
# HD30422
# GJ581
# HD98058
# ELIA3-1
# HD1461
# HD141569
# HD259431
# HD219482
# HD104237
# HD10008
# HD38397
# HD186219
# HD283571
# HD110411
# HD95086
# /fast/tgebhard/catnip/data/HD95086_15_094_C-0052_A/meta_information.json
# HD377
# HD35850
# HD142666
# TWA7
# /fast/tgebhard/catnip/data/TWA7_122_097_C-0653_B/meta_information.json
# HD163296
# PDS45
# /fast/tgebhard/catnip/data/PDS45_36_095_C-0456_A/meta_information.json
# TWA13B
# /fast/tgebhard/catnip/data/TWA13B_36_095_C-0456_A/meta_information.json
# HD181327
# HD22049
# HD17925
# HD169319
# /fast/tgebhard/catnip/data/HD169319_79_094_C-0608_A/meta_information.json
# HD193571
# GAIA DR1 4108644089918660736
# PDS66
# /fast/tgebhard/catnip/data/PDS66_122_097_C-0653_B/meta_information.json
# HD53143
# HD72660
# /fast/tgebhard/catnip/data/HD72660_49_096_C-0679_B/meta_information.json
# HD191089
# HD92945
# /fast/tgebhard/catnip/data/HD92945_36_095_C-0456_A/meta_information.json
# HD152404
# TWA25
# /fast/tgebhard/catnip/data/TWA25_36_095_C-0456_A/meta_information.json
# GJ3820
# HD59967
# HD92536
# HD97048
# HD98058
# HD142560
# HD38678
# HD43989
# HIP53911
# HD141569
# HD179218
# HD100453
# HD319139
# HD109573
# /fast/tgebhard/catnip/data/HD109573_36_095_C-0456_A/meta_information.json
# HD177171
# HD25457
# HD169142
# /fast/tgebhard/catnip/data/HD169142_79_094_C-0608_A/meta_information.json
# HD82558
# /fast/tgebhard/catnip/data/HD82558_36_095_C-0456_A/meta_information.json
# GAIA DR3 6010334804056742016
# HD145972
# HD118100
# HD64185
# HIP77157
# HD377
# HD110634
# HD123889
# HD100508
# GJ1054A
# HD181321
# ELIA2-27
# HD12894
# HD9672
# GAIA DR3 5995168724780802944
# HD44627
# HD18599
# HD178340
# HD202947
# /fast/tgebhard/catnip/data/HD202947_154_091_C-0154_A/meta_information.json
# /fast/tgebhard/catnip/data/HD202947_173_091_C-0154_A/meta_information.json
# /fast/tgebhard/catnip/data/HD202947_179_091_C-0154_A/meta_information.json
# GJ2079
# HD121191
# GAIA DR3 6112762833391909760
# WASP6
# HD63581
# HD92945
# GAIA DR3 3314132593936905600
# HD13183
# HD30501
# HD146181
# GJ3481
# HD32040
# HD138276
# /fast/tgebhard/catnip/data/HD138276_149_091_C-0154_A/meta_information.json
# HD70060
# /fast/tgebhard/catnip/data/HD70060_14_088_C-0406_A/meta_information.json
# HD172555
# PDS70
# /fast/tgebhard/catnip/data/PDS70_154_097_C-0206_A/meta_information.json
# HD103381
# PDS44
# HD145263
# HD107649
# HD12681
# /fast/tgebhard/catnip/data/HD12681_331_090_C-0486_A/meta_information.json
# GAIA DR3 5543639397065153536
# /fast/tgebhard/catnip/data/GAIA-DR3-5543639397065153536_105_1101_C-0092_E/meta_information.json
# HD139189
# HD177178
# HD135625
# HD32309
# HD224228
# /fast/tgebhard/catnip/data/HD224228_180_091_C-0154_A/meta_information.json
# HD181869
# /fast/tgebhard/catnip/data/HD181869_231_091_C-0654_A/meta_information.json
# HD134555
# HD103703
# HIP78053
# HD107146
# HD115820
# GJ1284
# GAIA DR3 3216729573251961856
# HD159492
# HD145666
# HD221853
# HD95086
# /fast/tgebhard/catnip/data/HD95086_178_291_C-5023_A/meta_information.json
# GJ871.1A
# HD135344B
# HD142
# /fast/tgebhard/catnip/data/HD142_320_082_C-0184_A/meta_information.json
# HD191849
# GAIA DR3 6049118388788178816
# HD206630
# HD111520
# GAIA DR3 4326511906643771904
# HD145964
# HD16978
# HD24966
# HD45270
# HD102458
# HD174429
# /fast/tgebhard/catnip/data/HD174429_270_085_C-0277_B/meta_information.json
# GJ3331
# HD217987
# TWA22
# HD111103
# HD24636
# GAIA DR2 2353128266975662080
# GJ358
# HD170209
# HD202206
# HD30447
# HD209100
# /fast/tgebhard/catnip/data/HD209100_285_0102_C-0592_A/meta_information.json
# /fast/tgebhard/catnip/data/HD209100_299_0102_C-0592_A/meta_information.json
# HD32195
# HD121617
# HD129590
# HD110058
# HD197481
# GAIA DR3 5481843025342799104
# PDS77
# HD191089
# HD153363
# HD164249
# HD10472
# HD185615
# HD19467
# HD207971
# HD135379
# HD218261
# HD72106
# HIP23309
# HD90905
# HIP55052
# HD218396
# HD31295
# HIP6276
# GAIA DR3 2886233695250041216
# HD142560
# HD38206
# HD38678
# HD178076
# /fast/tgebhard/catnip/data/HD178076_167_097_C-0972_A/meta_information.json
# HD142527
# HD28287
# GAIA DR3 5864061893213196032
# HD202398
# /fast/tgebhard/catnip/data/HD202398_173_091_C-0154_A/meta_information.json
# HD223352
# HD216956
# GAIA DR3 4880837088995421952
# HD68146
# HD11397
# HD57969
# /fast/tgebhard/catnip/data/HD57969_327_090_C-0486_A/meta_information.json
# HD207575
# HD138965
# HD103234
# HD131835
# GAIA DR3 6083750638577673088
# HD134888
# HD17250
# HD245409
# HD31026
# HD103743
# HD35850
# HD138813
# HD32297
# HD113556
# HD10647
# GAIA DR3 4719926581631285248
# HD143006
# HD181327
# HD159561
# HD4113
# HD177724
# HD168863
# HD181296
# HD115583
# HD219498
# GAIA DR3 4112557565383605632
# GAIA DR3 6080177569354209024
# GJ282C
# GAIA DR3 6243393817024157184
# GJ334
# HD70573
# HD124553
# HD67945
# /fast/tgebhard/catnip/data/HD67945_359_084_C-0739_A/meta_information.json
# HD54341
# HD43989
# HD3003
# /fast/tgebhard/catnip/data/HD3003_188_091_C-0154_A/meta_information.json
# HD215641
# HD71155
# HD21997
# HD78746
# HD109573
# GAIA DR3 2967055977510839680
# HD15115
# HD98800B
# HD25457
# WASP18
# GJ3305
# HD32576
# /fast/tgebhard/catnip/data/HD32576_327_090_C-0486_A/meta_information.json
# HD196544
# HD37484
# HD39060
# HD47306
# HD62850
# HD120326
# GAIA DR3 4742040410461492096
# GAIA DR3 6014722194741392512
# HD17438
# HD17848
# HD108767B
# /fast/tgebhard/catnip/data/HD108767B_38_094_C-0625_A/meta_information.json
# GAIA DR3 5997490206145065088
# GJ3102
# HD36968
# GJ281
# HD162020
# HD202116
# /fast/tgebhard/catnip/data/HD202116_179_091_C-0154_A/meta_information.json
# PDS43
# HD146897
# /fast/tgebhard/catnip/data/HD146897_223_1101_C-0092_I/meta_information.json
# HD984
# HD139664
# GAIA DR3 5997410491550194816
# HD116434
# HIP17157
# /fast/tgebhard/catnip/data/HIP17157_45_094_C-0625_A/meta_information.json
# HD112863
# HD85390
# GJ729
# HD105690
# HD14228
# HD131399A
# HD224392
# HD202953
# HD105613
# HD141521
# HD113524
# HD68475
# HD209952
# GJ900
# HD29391
# ELIA2-24
# HD109832
# HD141569
# HD361
# HIP82323
# /fast/tgebhard/catnip/data/HIP82323_202_1101_C-0092_H/meta_information.json
# HD104231
# HD10008
# HD38397
